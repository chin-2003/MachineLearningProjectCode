# %%
import pandas as pd

# %%
df = pd.read_csv("datafile.csv")

# %%
df
# Out:
#                    Crop  2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# 0                  Rice    100.0    101.0     99.0    105.0    112.0    121.0
# 1                 Wheat    100.0    101.0    112.0    115.0    117.0    127.0
# 2        Coarse Cereals    100.0    107.0    110.0    115.0    113.0    123.0
# 3                Pulses    100.0    108.0    134.0    124.0    124.0    146.0
# 4           Vegetables     100.0    109.0    103.0    118.0    113.0    124.0
# 5                Fruits    100.0     99.0     99.0     98.0    102.0    104.0
# 6                  Milk    100.0     97.0     98.0     98.0     98.0    112.0
# 7   Eggs, Fish and Meat    100.0    102.0    101.0    100.0     99.0    116.0
# 8              Oilseeds    100.0     86.0     85.0     97.0    104.0    103.0
# 9            Sugarcane     100.0     96.0     91.0     87.0     80.0     81.0
# 10               Fibers    100.0     92.0     91.0     96.0    109.0    107.0
# ...

# %%
df.shape
# Out:
# (13, 9)

# %%
df.dropna(inplace = True)

# %%
df.describe()
# Out:
#        2004-05    2005-06     2006-07     2007-08     2008-09     2009-10  \
# count     12.0   12.00000   12.000000   12.000000   12.000000   12.000000
# mean     100.0   99.75000  102.000000  104.750000  106.416667  114.916667
# std        0.0    6.64865   12.634728   10.963783   11.261022   15.900019
# min      100.0   86.00000   85.000000   87.000000   80.000000   81.000000
# 25%      100.0   96.75000   96.250000   97.750000  101.250000  106.250000
# 50%      100.0  100.00000  100.000000  102.000000  107.500000  115.500000
# 75%      100.0  103.25000  104.750000  115.000000  113.000000  123.250000
# max      100.0  109.00000  134.000000  124.000000  124.000000  146.000000
#
#           2010-11     2011-12
# count   12.000000   12.000000
# mean   121.916667  120.750000
# std     11.405408   12.800036
# min     99.000000  102.000000
# 25%    116.250000  109.500000
# 50%    122.500000  120.500000
# 75%    129.250000  130.750000
# max    138.000000  140.000000

# %%
df1 = pd.read_csv("datafile-1.csv")

# %%
df1
# Out:
#                     Crop           State  \
# 0                  ARHAR   Uttar Pradesh
# 1                  ARHAR       Karnataka
# 2                  ARHAR         Gujarat
# 3                  ARHAR  Andhra Pradesh
# 4                  ARHAR     Maharashtra
# 5                 COTTON     Maharashtra
# 6                 COTTON          Punjab
# 7                 COTTON  Andhra Pradesh
# 8                 COTTON         Gujarat
# 9                 COTTON         Haryana
# 10                  GRAM       Rajasthan
# 11                  GRAM  Madhya Pradesh
# 12                  GRAM   Uttar Pradesh
# 13                  GRAM     Maharashtra
# 14                  GRAM  Andhra Pradesh
# 15             GROUNDNUT       Karnataka
# 16             GROUNDNUT  Andhra Pradesh
# 17             GROUNDNUT      Tamil Nadu
# 18             GROUNDNUT         Gujarat
# 19             GROUNDNUT     Maharashtra
# 20                 MAIZE           Bihar
# 21                 MAIZE       Karnataka
# ...

# %%
df1.shape
# Out:
# (49, 6)

# %%
df1.describe()
# Out:
#        Cost of Cultivation (`/Hectare) A2+FL  \
# count                              49.000000
# mean                            20363.537347
# std                             13561.435306
# min                              5483.540000
# 25%                             12774.410000
# 50%                             17022.000000
# 75%                             24731.060000
# max                             66335.060000
#
#        Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2  \
# count                           49.000000                          49.000000
# mean                         31364.666735                        1620.537755
# std                          20095.783569                        1104.990472
# min                           7868.640000                          85.790000
# 25%                          19259.840000                         732.620000
# 50%                          25909.050000                        1595.560000
# ...

# %%
df2 = pd.read_csv("datafile-2.csv")

# %%
df2
# Out:
#             Crop               Production 2006-07  Production 2007-08  \
# 0            Total Foodgrains               158.8               168.6
# 1                        Rice               200.8               207.9
# 2                       Wheat               131.6               136.4
# 3                       Jowar               124.3               137.8
# 4                       Bajra               136.4               161.5
# 5                       Maize               198.8               249.6
# 6                        Ragi                56.1                83.6
# 7               Small millets                53.9                61.9
# 8                      Barley                88.1                79.3
# 9              Coarse Cereals               138.5               166.4
# 10                    Cereals               164.1               174.6
# 11                       Gram               140.6               127.6
# ...

# %%
df2.shape
# Out:
# (55, 16)

# %%
df2.describe()
# Out:
#        Production 2006-07  Production 2007-08  Production 2008-09  \
# count           55.000000           55.000000           55.000000
# mean           168.698182          182.629091          179.952727
# std            179.503163          199.671545          187.409253
# min             53.900000           54.400000           50.000000
# 25%            124.500000          122.200000          116.050000
# 50%            142.700000          160.100000          156.500000
# 75%            184.300000          200.100000          188.550000
# max           1427.700000         1571.500000         1463.000000
#
#        Production 2009-10  Production 2010-11  Area 2006-07  Area 2007-08  \
# count           55.000000           55.000000     55.000000     55.000000
# mean           173.749091          210.181818    116.025455    118.403636
# std            184.231322          232.535985     37.990960     41.287797
# min             42.900000           42.100000     47.900000     47.400000
# ...

# %%
df3 = pd.read_csv("datafile-3.csv")

# %%
df3
# Out:
#            Crop                     Variety Season/ duration in days  \
# 0         Paddy  Chinsurah Rice (IET 19140)                   Medium
# 1         Paddy              (CNI 383-5-11)                      NaN
# 2         Paddy         IGKVR-1 (IET 19569)                Mid-early
# 3         Paddy         IGKVR-2 (IET 19795)                   Medium
# 4         Paddy        CR Dhan 401 (REETA)                   145-150
# ..          ...                         ...                      ...
# 73        Mesta            SHRESTHA (JRM-5)                        -
# 74       Cotton                      CNH012                      165
# 75       Cotton           CICR-3 (CISA 614)                      150
# 76       Cotton                   VBCH 2231                      NaN
# 77  Desi Cotton                     FDK 124                      NaN
#
#                                      Recommended Zone  Unnamed: 4
# 0   Andhra Pradesh, Tamil Nadu, Gujarat, Orissa, a...         NaN
# ...

# %%
df3.drop(df3.columns[4], axis = 1, inplace = True)

# %%
df3.dropna(inplace = True)

# %%
df3.reset_index(inplace = True)

# %%
df3
# Out:
#     index             Crop                         Variety  \
# 0       0            Paddy      Chinsurah Rice (IET 19140)
# 1       2            Paddy             IGKVR-1 (IET 19569)
# 2       3            Paddy             IGKVR-2 (IET 19795)
# 3       4            Paddy            CR Dhan 401 (REETA)
# 4       5            Paddy         CR Dhan 601 (IET 18558)
# 5       6            Paddy         CR Dhan 501 (IET 19189)
# 6       7            Paddy      RC Maniphou 11 (IET 20193)
# 7       8            Wheat        MPO(JW)  1215 (MPO 1215)
# 8       9            Wheat                       MACS 6222
# 9      10            Wheat                         PDW 314
# 10     11            Wheat                           DBW39
# 11     12            Wheat           VL Gehun 907 (VL 907)
# 12     17           Barley                          BH-902
# 13     19           Barley           Pusa Losar  (BH- 380)
# 14     20            Maize                            HSC1
# ...

# %%
df3.shape
# Out:
# (50, 5)

# %%
df3.describe()
# Out:
#           index
# count  50.00000
# mean   36.40000
# std    22.98713
# min     0.00000
# 25%    17.50000
# 50%    37.50000
# 75%    53.50000
# max    75.00000

# %%
df4 = pd.read_csv("produce.csv")

# %%
df4
# Out:
#                                            Particulars  \
# 0                   Agricultural Production Foodgrains
# 1            Agricultural Production Foodgrains Kharif
# 2              Agricultural Production Foodgrains Rabi
# 3              Agricultural Production Foodgrains Rice
# 4       Agricultural Production Foodgrains Rice Kharif
# ..                                                 ...
# 424  Agricultural Production Foodgrains Coarse Cere...
# 425  Agricultural Production Foodgrains Coarse Cere...
# 426  Agricultural Production Foodgrains Coarse Cere...
# 427  Agricultural Production Foodgrains Coarse Cere...
# 428  Agricultural Production Foodgrains Coarse Cere...
#
#                            Frequency    Unit   3-1993   3-1994   3-1995  \
# 0    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 1    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 2    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# ...

# %%
df4.fillna((0))
# Out:
#                                            Particulars  \
# 0                   Agricultural Production Foodgrains
# 1            Agricultural Production Foodgrains Kharif
# 2              Agricultural Production Foodgrains Rabi
# 3              Agricultural Production Foodgrains Rice
# 4       Agricultural Production Foodgrains Rice Kharif
# ..                                                 ...
# 424  Agricultural Production Foodgrains Coarse Cere...
# 425  Agricultural Production Foodgrains Coarse Cere...
# 426  Agricultural Production Foodgrains Coarse Cere...
# 427  Agricultural Production Foodgrains Coarse Cere...
# 428  Agricultural Production Foodgrains Coarse Cere...
#
#                            Frequency    Unit   3-1993   3-1994   3-1995  \
# 0    Annual, Ending mar Of Each Year  Ton mn      0.0      0.0      0.0
# 1    Annual, Ending mar Of Each Year  Ton mn      0.0      0.0      0.0
# 2    Annual, Ending mar Of Each Year  Ton mn      0.0      0.0      0.0
# ...

# %%
data = df.iloc[:,0:1]

# %%
data1 = df1.iloc[:,0:5]

# %%
data2 = df2.iloc[:,0:6]

# %%
data3 = df3.iloc[:,1:5]

# %%
data4 = df4.iloc[:,0:3]

# %%
merged_data = pd.concat([data,data1,data2,data3,data4])

# %%
merged_data
# Out:
#                Crop State  Cost of Cultivation (`/Hectare) A2+FL  \
# 0              Rice   NaN                                    NaN
# 1             Wheat   NaN                                    NaN
# 2    Coarse Cereals   NaN                                    NaN
# 3            Pulses   NaN                                    NaN
# 4       Vegetables    NaN                                    NaN
# ..              ...   ...                                    ...
# 424             NaN   NaN                                    NaN
# 425             NaN   NaN                                    NaN
# 426             NaN   NaN                                    NaN
# 427             NaN   NaN                                    NaN
# 428             NaN   NaN                                    NaN
#
#      Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2  \
# 0                                   NaN                                NaN
# ...

# %%
merged_data1 = merged_data.fillna((0))

# %%
merged_data.describe()
# Out:
#        Cost of Cultivation (`/Hectare) A2+FL  \
# count                              49.000000
# mean                            20363.537347
# std                             13561.435306
# min                              5483.540000
# 25%                             12774.410000
# 50%                             17022.000000
# 75%                             24731.060000
# max                             66335.060000
#
#        Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2  \
# count                           49.000000                          49.000000
# mean                         31364.666735                        1620.537755
# std                          20095.783569                        1104.990472
# min                           7868.640000                          85.790000
# 25%                          19259.840000                         732.620000
# 50%                          25909.050000                        1595.560000
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2008-09'])
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2008-09')
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2009-10'])
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2009-10')
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2010-11'])
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2010-11')
# Out:
# Text(0, 0.5, 'Production 2010-11')

# %%
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2008-09'])
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2008-09')
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2009-10'])
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2009-10')
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2010-11'])
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2010-11')
# Out:
# Text(0, 0.5, 'Production 2010-11')

# %%
plt.scatter(merged_data1['Cost of Production (`/Quintal) C2'],merged_data1['Production 2008-09'])
plt.xlabel('Cost of Production (`/Quintal) C2')
plt.ylabel('Production 2008-09')
plt.scatter(merged_data1['Cost of Production (`/Quintal) C2'],merged_data1['Production 2009-10'])
plt.xlabel('Cost of Production (`/Quintal) C2')
plt.ylabel('Production 2009-10')
plt.scatter(merged_data1['Cost of Production (`/Quintal) C2'],merged_data1['Production 2010-11'])
plt.xlabel('Cost of Production (`/Quintal) C2')
plt.ylabel('Production 2010-11')
# Out:
# Text(0, 0.5, 'Production 2010-11')

# %%
X = merged_data1.iloc[:,2:5]

# %%
y = merged_data1.iloc[:,8:11]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      Cost of Cultivation (`/Hectare) A2+FL  \
# 269                                   0.00
# 419                                   0.00
# 38                                    0.00
# 17                                    0.00
# 223                                   0.00
# ..                                     ...
# 80                                    0.00
# 176                                   0.00
# 6                                 29047.10
# 41                                55655.44
# 59                                    0.00
#
#      Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2
# 269                                0.00                               0.00
# 419                                0.00                               0.00
# 38                                 0.00                               0.00
# 17                                 0.00                               0.00
# ...

# %%
y_test
# Out:
#      Production 2008-09  Production 2009-10  Production 2010-11
# 269                 0.0                 0.0                 0.0
# 419                 0.0                 0.0                 0.0
# 38                  0.0                 0.0                 0.0
# 17                  0.0                 0.0                 0.0
# 223                 0.0                 0.0                 0.0
# ..                  ...                 ...                 ...
# 80                  0.0                 0.0                 0.0
# 176                 0.0                 0.0                 0.0
# 6                   0.0                 0.0                 0.0
# 41                  0.0                 0.0                 0.0
# 59                  0.0                 0.0                 0.0
#
# [119 rows x 3 columns]

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ -6.79205731,  -6.5480075 ,  -7.90180825],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
#        [ 19.45094121,  18.75203684,  22.62902102],
# ...

# %%
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2008-09'])
plt.plot(X_train,lr.predict(X_train),color = 'green')
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2008-09')
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2009-10'])
plt.plot(X_train,lr.predict(X_train),color = 'red')
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2009-10')
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2010-11'])
plt.plot(X_train,lr.predict(X_train),color = 'blue')
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2010-11')
# Out:
# Text(0, 0.5, 'Production 2010-11')

# %%
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2008-09'])
plt.plot(X_train,lr.predict(X_train),color = 'green')
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2008-09')
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2009-10'])
plt.plot(X_train,lr.predict(X_train),color = 'red')
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2009-10')
plt.scatter(merged_data1['Cost of Cultivation (`/Hectare) A2+FL'],merged_data1['Production 2010-11'])
plt.plot(X_train,lr.predict(X_train),color = 'blue')
plt.xlabel('Cost of Cultivation (`/Hectare) A2+FL')
plt.ylabel('Production 2010-11')
# Out:
# Text(0, 0.5, 'Production 2010-11')

# %%
plt.scatter(merged_data1['Cost of Production (`/Quintal) C2'],merged_data1['Production 2008-09'])
plt.plot(X_train,lr.predict(X_train),color = 'green')
plt.xlabel('Cost of Production (`/Quintal) C2')
plt.ylabel('Production 2008-09')
plt.scatter(merged_data1['Cost of Production (`/Quintal) C2'],merged_data1['Production 2009-10'])
plt.plot(X_train,lr.predict(X_train),color = 'red')
plt.xlabel('Cost of Production (`/Quintal) C2')
plt.ylabel('Production 2009-10')
plt.scatter(merged_data1['Cost of Production (`/Quintal) C2'],merged_data1['Production 2010-11'])
plt.plot(X_train,lr.predict(X_train),color = 'blue')
plt.xlabel('Cost of Production (`/Quintal) C2')
plt.ylabel('Production 2010-11')
# Out:
# Text(0, 0.5, 'Production 2010-11')

# %%
m = lr.coef_
print(m)
# Out:
# [[ 0.00085083 -0.00087142 -0.00505549]
#  [ 0.00082026 -0.00084011 -0.00487384]
#  [ 0.00098985 -0.0010138  -0.0058815 ]]

# %%
b = lr.intercept_
print(b)
# Out:
# [19.45094121 18.75203684 22.62902102]

# %%
# y = mx + b
m * 67.2 + b
# Out:
# array([[19.50811709, 18.69347725, 22.28929209],
#        [19.50606266, 18.69558139, 22.30149911],
#        [19.51745903, 18.68390922, 22.23378395]])

# %%
from sklearn.metrics import mean_absolute_error

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(y_test,y_pred)
print(f"Mean Absolute Error:{mae:2f}")
# Out:
# Mean Absolute Error:28.179172

# %%
from sklearn.metrics import mean_squared_error

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(y_test,y_pred)
print(f"Mean Squared Error:{mse:2f}")
# Out:
# Mean Squared Error:2128.150014
